# %% [markdown]
# #**HW 3: Convolutional Neural Networks**
#
# In this homework, we will explore how to develop a simple Convolutional Neural Network for image classification. We will use the Fashion Minst dataset. In the first part, we will learn how to develop a simple CNN, while in the second part we will explore the impact of various hyper-parameters in the learning performances.

# %% [markdown]
# ##Exercise 3.1: Simple CNN
#
# Let's start by importing Tensorflow, Keras and Numpy

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

# %% [markdown]
# ###Load dataset:
# ### Load Data: Fashion MNIST dataset
#
# We will use the Fashion MNIST dataset, a dataset of Zalando's articles. Each sample is a 28x28 pixels grayscale image, associated with a label from 10 classes:
#
# class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
#
# Each pixel intensity is represented by a uint8 (byte) from 0 to 255.
# We will divide the dataset in training, validation and test set. As you already know, the training set will be used to train the model, the validation set will be used to perform model selection and finally, the test set will be used to asses the performance of the deep network.
#
# Since we will use a [2DConv](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) we have to provide also a new dimension of the input that represents the number of channels (that in grey scale image is just one). Therefore we use [tf.expand_dims](https://www.tensorflow.org/api_docs/python/tf/expand_dims) to transform each image from a matrix to a 3-dimensional tensor. Finaly we have to normalize the input data.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = (
    fashion_mnist.load_data()) #The dataset is already divede in test and training..

#We extract the first 5000 samples of the training set, to use them as the validation set
X_valid, X_train = X_train_full[:5000], X_train_full[5000:] 
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]



class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]


#print(X_train)

#print(X_train - X_train.mean() )
#print(X_train.std())

# %% [markdown]
# Let's take a look at a sample of the images in the dataset:

# %%
n_rows = 5
n_cols = 10
plt.figure(figsize=(n_cols*1.4, n_rows * 1.6))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]])
plt.show()

# %% [markdown]
# ### [TO COMPLETE] Input Normalization:
#
# When using Gradient Descent, it is usually a good idea to ensure that all the features have a similar scale. Try to standardize the pixel values.

# %%
#[TO COMPLETE]: define X_train_scaled, X_valid_scaled and X_test_scaled, the sets that contains 
#Hint: For each feature (pixel intensity), you must subtract the mean() of that 
#feature (across all instances, so use axis=0) and divide by its standard 
#deviation (std(), again axis=0)






X_train = (X_train - X_train.mean() ) / X_train.std()
X_valid = (X_valid - X_valid.mean() ) / X_valid.std()
X_test = (X_test - X_test.mean() ) / X_test.std()


#Add one dimension to manage the channel
X_train=tf.expand_dims(X_train, 3) 
X_valid=tf.expand_dims(X_valid, 3) 
X_test=tf.expand_dims(X_test,3)

#Make sure you compute the means and standard deviations on the training set,
#and use these statistics to scale the training set, the validation set and the
# test set

# %% [markdown]
# ###Define the model
#
# Let's create a simple CNN. The model will be composed of:
# * One 2D convolutional layer with kernel size 3x3 and 32 output filters/features, that use ReLu activation function
# * a Max Pooling layer (2D) of size 2x2 ([MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D))
# * a Flatten layer
# * a final Dense layer with 10 output neurons (one per class), and with the "softmax" activation function to ensure that the sum of all the estimated class probabilities for each image is equal to 1.
# Note that as 'input_shape' attribute's value in the first layer report also the third dimension that represents the channel.

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=[3,3], padding="same", activation="relu", input_shape=[28, 28,1]),
    keras.layers.MaxPool2D(pool_size=[2,2]),
    keras.layers.Flatten(),
    keras.layers.Dense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy",
              optimizer='sgd',
              metrics=["accuracy"])

# %% [markdown]
# Print the model summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                62730
# =================================================================
# Total params: 63,050
# Trainable params: 63,050
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Note that the number of parameters mostly depends on the output layers, indeed the parameter sharing techinique used by the 2D convolutional layers allows to significantly reduce the number of learnable weights.
# Now we can train the model.

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=128,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 430/430 [==============================] - 22s 49ms/step - loss: 1.1382 - accuracy: 0.6570 - val_loss: 0.5291 - val_accuracy: 0.8216
# Epoch 2/10
# 430/430 [==============================] - 20s 48ms/step - loss: 0.5129 - accuracy: 0.8232 - val_loss: 0.4479 - val_accuracy: 0.8472
# Epoch 3/10
# 430/430 [==============================] - 20s 48ms/step - loss: 0.4531 - accuracy: 0.8431 - val_loss: 0.4110 - val_accuracy: 0.8630
# Epoch 4/10
# 430/430 [==============================] - 20s 48ms/step - loss: 0.4198 - accuracy: 0.8537 - val_loss: 0.3962 - val_accuracy: 0.8654
# Epoch 5/10
# 430/430 [==============================] - 21s 48ms/step - loss: 0.3972 - accuracy: 0.8601 - val_loss: 0.3859 - val_accuracy: 0.8708
# Epoch 6/10
# 430/430 [==============================] - 21s 48ms/step - loss: 0.3710 - accuracy: 0.8719 - val_loss: 0.3781 - val_accuracy: 0.8744
# Epoch 7/10
# 430/430 [==============================] - 20s 48ms/step - loss: 0.3631 - accuracy: 0.8728 - val_loss: 0.3614 - val_accuracy: 0.8738
# Epoch 8/10
# 430/430 [==============================] - 21s 48ms/step - loss: 0.3525 - accuracy: 0.8764 - val_loss: 0.3542 - val_accuracy: 0.8812
# Epoch 9/10
# 430/430 [==============================] - 20s 47ms/step - loss: 0.3450 - accuracy: 0.8772 - val_loss: 0.3404 - val_accuracy: 0.8864
# Epoch 10/10
# 430/430 [==============================] - 21s 48ms/step - loss: 0.3351 - accuracy: 0.8830 - val_loss: 0.3373 - val_accuracy: 0.8848

# %% [markdown]
# Plot the loss and the accuracy trends for the training and validation set. Then, compute the result on the test set.

# %%
def plot_loss(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['loss'])
  plt.plot(history.epoch,history.history['val_loss'])
  plt.title('loss')

def plot_accuracy(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['accuracy'])
  plt.plot(history.epoch,history.history['val_accuracy'])
  plt.title('accuracy')

plot_loss(history)

plot_accuracy(history)

scores = model.evaluate(X_test, y_test, verbose=2)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 313/313 - 2s - loss: 0.2704 - accuracy: 0.9034
# accuracy: 90.34%

# %% [markdown]
# ###Visualize Weights
#
# An interesting thing to do is to visualize the learned weights for the convolutional layer. We have 32 kernels of size 3x3, we can just plot them as images, mapping the weight values to grayscale.

# %%
# Weights for the first convolutional layer
w0=model.get_weights()[0][:,:,0,:]

# Normalize to range 0.0 - 1.0
w0-=np.min(w0)
w0/=np.max(w0)

for r in range(4):
    for c in range(8):
        n=r*8+c
        plt.subplot(4, 8, n+1)
        plt.imshow(w0[:,:,n], interpolation='none')
        plt.axis('off')
        plt.gray()
plt.show()

# %% [markdown]
# They might be a bit hard to interpret, but it seems that the various filters have learned to detect various corners and edges.

# %% [markdown]
# ### [TO COMPLETE] Deep CNN
# Let's consider a deeper model, more precily in this exercise we consider a model composed of:
# * One 2D convolutional layer with kernel size 3x3 and 32 output filters/features, that use ReLu activation function
# * a Max Pooling layer (2D) of size 2x2
# * One 2D convolutional layer with kernel size 2x2 and 16 output filters/features, that use ReLu activation function
# * a Max Pooling layer (2D) of size 2x2
# * a Flatten layer
# * a final Dense layer with 10 output neurons (one per class), and with the "softmax" activation function

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=[3,3], activation='relu', input_shape=[28, 28,1]),
    keras.layers.MaxPool2D(pool_size=[2,2]),
    keras.layers.Conv2D(filters=16, kernel_size=[2,2], activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(10, activation="softmax")
  ])
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])
  
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 16)        2064
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5770
# =================================================================
# Total params: 8,154
# Trainable params: 8,154
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# [TO COMPLETE] Explain in this cell:
#
# 1.   how the number of parameters on each of the two Conv2D layers is determined;
# 2.   the reasons why the two considered convolutional layers have a different number of parameters.
#
# Answers:
#
#
# 1.  param_number = output_channel_number * (input_channel_number * kernel_height * kernel_width + 1)
#  ; 32*(1* 3*3 + 1)= 320
#
#
# 2.
# This because they have different kerner size and input and output channel after polling function.

# %% [markdown]
# Let's now train our deep CNN.

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=128,
                  validation_data=(X_valid, y_valid))

plot_loss(history)
plot_accuracy(history)

scores = model.evaluate(X_test, y_test, verbose=2)
print(" %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print("----------------------------")
# Out:
# Epoch 1/10
# 430/430 [==============================] - 24s 56ms/step - loss: 1.5654 - accuracy: 0.4718 - val_loss: 0.7123 - val_accuracy: 0.7630
# Epoch 2/10
# 430/430 [==============================] - 24s 55ms/step - loss: 0.6969 - accuracy: 0.7507 - val_loss: 0.5715 - val_accuracy: 0.7992
# Epoch 3/10
# 430/430 [==============================] - 24s 56ms/step - loss: 0.5694 - accuracy: 0.7976 - val_loss: 0.5134 - val_accuracy: 0.8192
# Epoch 4/10
# 430/430 [==============================] - 24s 56ms/step - loss: 0.5065 - accuracy: 0.8195 - val_loss: 0.5027 - val_accuracy: 0.8198
# Epoch 5/10
# 430/430 [==============================] - 24s 56ms/step - loss: 0.4642 - accuracy: 0.8331 - val_loss: 0.4340 - val_accuracy: 0.8516
# Epoch 6/10
# 430/430 [==============================] - 24s 56ms/step - loss: 0.4465 - accuracy: 0.8412 - val_loss: 0.4156 - val_accuracy: 0.8584
# Epoch 7/10
# 430/430 [==============================] - 24s 56ms/step - loss: 0.4224 - accuracy: 0.8497 - val_loss: 0.4582 - val_accuracy: 0.8410
# Epoch 8/10
# 430/430 [==============================] - 24s 56ms/step - loss: 0.4129 - accuracy: 0.8491 - val_loss: 0.4001 - val_accuracy: 0.8628
# Epoch 9/10
# 430/430 [==============================] - 24s 57ms/step - loss: 0.4019 - accuracy: 0.8560 - val_loss: 0.4137 - val_accuracy: 0.8546
# Epoch 10/10
# 430/430 [==============================] - 24s 56ms/step - loss: 0.3874 - accuracy: 0.8610 - val_loss: 0.3908 - val_accuracy: 0.8662
# 313/313 - 2s - loss: 0.4086 - accuracy: 0.8539
#  accuracy: 85.39%
# ----------------------------

# %% [markdown]
# ## [TO COMPLETE] Exercise 3.2: Develop a better CNN
# Let's develop a network that performs better than the very simple one above. This exercise aims to explore how much the various hyper-parameters influence the classification capability of the model.
#
# **[TO COMPLETE]**: Your task is to modify some of the hyper-parameters of the previous exercise's network and compare the results. At least one of the models you try should have an improvement in the test set results (generalization) over the result of the model used in the previous exercise.
# In the cell below report only the code of the **best model** that you can find. In addtion, print out its result on the test set, and plot the accuracy and the loss trends in the notebook you return.
# Moreover, for each setup you test, analyze and discuss the obtained results briefly in the last cells at the bottom.
#
# Hint: Each reparameterization should change a different aspect in the network, while the rest of the parameters would stay the same.
# Example parameters to try to change (we suggest to test at least one re-parametrization for each of these categories):
#
# *    number of layers or neurons or filters dimension
# *   activation functions
# *   epochs
# *   batch sizes
# *   optimizer, see TensorFlow documentation on [optimizers](https://https://www.tensorflow.org/api_docs/python/tf/keras/optimizers)
# *   max-pooling on/off on certain layers, or pool size
#
# For what concerns the optimizer, as you can see in the 'compile' method [documentation](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile) is it possible to pass as 'optimizer ' attribute's value a string (the name of optimizer) or an optimizer instance.
#
# Notice that changing the final layer's softmax activation plus the categorical_crossentropy loss requires some consideration. Don't do it unless you have a good plan.

# %%
#Deep CNN
model = keras.models.Sequential([
    keras.layers.Conv2D(filters=64, kernel_size=[3,3], activation='relu', input_shape=[28, 28,1]), 
    keras.layers.MaxPool2D(pool_size=[2,2]),
    keras.layers.Conv2D(filters=32, kernel_size=[2,2], activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(10, activation="softmax")
  ])
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])


history = model.fit(X_train, y_train, epochs=10, batch_size=128,
                  validation_data=(X_valid, y_valid))

plot_loss(history)
plot_accuracy(history)

scores = model.evaluate(X_test, y_test, verbose=2)
print(" %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print("----------------------------")
# Out:
# Epoch 1/10
# 430/430 [==============================] - 41s 94ms/step - loss: 0.8242 - accuracy: 0.7257 - val_loss: 0.3800 - val_accuracy: 0.8678
# Epoch 2/10
# 430/430 [==============================] - 40s 93ms/step - loss: 0.3610 - accuracy: 0.8712 - val_loss: 0.3296 - val_accuracy: 0.8878
# Epoch 3/10
# 430/430 [==============================] - 40s 92ms/step - loss: 0.3161 - accuracy: 0.8877 - val_loss: 0.3191 - val_accuracy: 0.8934
# Epoch 4/10
# 430/430 [==============================] - 40s 92ms/step - loss: 0.2928 - accuracy: 0.8975 - val_loss: 0.3054 - val_accuracy: 0.8886
# Epoch 5/10
# 430/430 [==============================] - 40s 92ms/step - loss: 0.2764 - accuracy: 0.9009 - val_loss: 0.2835 - val_accuracy: 0.9002
# Epoch 6/10
# 430/430 [==============================] - 40s 93ms/step - loss: 0.2667 - accuracy: 0.9057 - val_loss: 0.2766 - val_accuracy: 0.9016
# Epoch 7/10
# 430/430 [==============================] - 40s 92ms/step - loss: 0.2457 - accuracy: 0.9119 - val_loss: 0.2683 - val_accuracy: 0.9048
# Epoch 8/10
# 430/430 [==============================] - 40s 92ms/step - loss: 0.2407 - accuracy: 0.9146 - val_loss: 0.2570 - val_accuracy: 0.9096
# Epoch 9/10
# 430/430 [==============================] - 40s 92ms/step - loss: 0.2284 - accuracy: 0.9190 - val_loss: 0.2823 - val_accuracy: 0.8998
# Epoch 10/10
# 430/430 [==============================] - 40s 92ms/step - loss: 0.2290 - accuracy: 0.9174 - val_loss: 0.2498 - val_accuracy: 0.9116
# 313/313 - 2s - loss: 0.2718 - accuracy: 0.9051
#  accuracy: 90.51%
# ----------------------------

# %% [markdown]
# ### [TO COMPLETE] Example of tests discussion
# The best model that I found has 64 filters at first convolutional layer and 32 filters at second.
#
#
# The achieved accuracy in the test set : 90.51%.
#
# Discussion:
# - Since in Cnn the weights are shared , having more filters means have more weights for find the better model.
# - Doubling the number of filters increase the accuracy of model.
# - The optimizer "adam"  is the best one. Using others optimizer like Adagrad,Adamax,Nadam  give fairly good performance but still lower than adam
# - The best activation function is Relu

# %% [markdown]
# Besides, I tested also other models:
# - Using sigmoide or other activation function give bad performance.
# -Increasing batch size dont influenze performance in
# relevant way. However the computation time increase a lot.
# - Adding more convolutional layers, the performace dont increase and the best is having only 2 layers.
#
#
#
# Discussion:
# After testing many model with different hyperparameters, i find the best set is given by above and since they are priori-knoledge hyper-parameters, it can be said, with certainly, they are not the optimal set. We can try to find the optimal set using for example Gridsearch and test all possible combination.
# Of course, this will take a lot of computation time.
